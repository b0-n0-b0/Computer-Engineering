# %% [markdown]
# # Homework exercises (if you want)

# %% [markdown]
# ### 1. Write down a 3-qubits circuit which outputs a 3-qubit Bell state $\frac{1}{\sqrt(2)}(\vert000\rangle + \vert111\rangle)$

# %% [markdown]
# ### 2. Try to generalize Exercise 1 to an $n$ qubit state $\frac{1}{\sqrt(2)}(\vert00\dots0\rangle + \vert11\dots1\rangle)$

# %% [markdown]
# ### 3. Execute your circuit and verify the outcomes
