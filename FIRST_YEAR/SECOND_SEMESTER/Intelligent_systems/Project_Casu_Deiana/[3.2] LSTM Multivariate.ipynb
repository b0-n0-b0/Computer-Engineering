# %% [markdown]
# # **Bulding a LSTM multivariate model**

# %%
# !pip install tensorflow --quiet
# !pip install yfinance   --quiet

import math as mt
import numpy as np
import pandas as pd
import yfinance as yf
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tensorflow import keras
from seaborn import set_style
from sklearn.preprocessing import MinMaxScaler

set_style("darkgrid")

# For reproducibility
np.random.seed(24)
tf.random.set_seed(24)

# %%
start_date = "2020-06-24"
end_date   = "2023-06-24"

apple_ticker  = "AAPL"
smsg_ticker   = "005930.KS" # Ticker symbol for Samsung on Korea Stock Exchange (KS)

amazon_ticker = "AMZN"
baba_ticker   = "BABA"  # Ticker symbol for Alibaba Group on NYSE

AAPL = yf.download(apple_ticker, start=start_date, end=end_date)
SMSG = yf.download(smsg_ticker, start=start_date, end=end_date)

AMZN = yf.download(amazon_ticker, start=start_date, end=end_date)
BABA = yf.download(baba_ticker, start=start_date, end=end_date)

AAPL.index = pd.to_datetime(AAPL.index)
AMZN.index = pd.to_datetime(AMZN.index)
BABA.index = pd.to_datetime(BABA.index)
SMSG.index = pd.to_datetime(SMSG.index)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
SMSG.tail()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2023-06-19  71300.0  71700.0  70900.0  71200.0    71200.0  11100887
# 2023-06-20  70700.0  71400.0  70400.0  71400.0    71400.0  11557883
# 2023-06-21  70700.0  71200.0  70400.0  70500.0    70500.0  10626603
# 2023-06-22  70200.0  71500.0  70100.0  71300.0    71300.0  11411007
# 2023-06-23  72000.0  72200.0  71600.0  71600.0    71600.0  12329484

# %%
BABA.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-06-16  94.000000  94.290001  91.519997  92.099998  92.099998  25048200
# 2023-06-20  89.830002  90.199997  87.320000  87.930000  87.930000  23382900
# 2023-06-21  87.379997  89.160004  86.620003  86.769997  86.769997  15159900
# 2023-06-22  86.779999  87.315002  85.320000  86.889999  86.889999  10272700
# 2023-06-23  85.809998  85.938004  84.370003  84.919998  84.919998  14830800

# %% [markdown]
# Before starting the analysis, it is necessary to understand that there exists a correlation (or anticorrelation) between the returns of a company and the chosen competitor.

# %%
AAPL['AAPL Close']  = AAPL['Close']
AAPL['AAPL Volume'] = AAPL['Volume']

# SK WON to USD (08-07-2023):
WON_USD = 0.000770
SMSG['SMSG Close']  = SMSG['Close'] * WON_USD
SMSG['SMSG Volume'] = SMSG['Volume']

AAPL = AAPL.drop(['Open','High','Low','Close','Adj Close','Volume'], axis=1)
SMSG = SMSG.drop(['Open','High','Low','Close','Adj Close','Volume'], axis=1)


AMZN['AMZN Close']  = AMZN['Close']
AMZN['AMZN Volume'] = AMZN['Volume']

BABA['BABA Close']  = BABA['Close']
BABA['BABA Volume'] = BABA['Volume']

AMZN = AMZN.drop(['Open','High','Low','Close','Adj Close','Volume'], axis=1)
BABA = BABA.drop(['Open','High','Low','Close','Adj Close','Volume'], axis=1)


# Merge the two DataFrames based on 'Date' column
AAPL_SMSG = pd.merge(AAPL, SMSG, on='Date', how='inner')
AMZN_BABA = pd.merge(AMZN, BABA, on='Date', how='inner')

# %%
T = 21

AAPL_returns = AAPL_SMSG['AAPL Close'] - AAPL_SMSG['AAPL Close'].shift(T)
SMSG_returns = AAPL_SMSG['SMSG Close'] - AAPL_SMSG['SMSG Close'].shift(T)

AMZN_returns = AMZN_BABA['AMZN Close'] - AMZN_BABA['AMZN Close'].shift(T)
BABA_returns = AMZN_BABA['BABA Close'] - AMZN_BABA['BABA Close'].shift(T)

AAPL_SMSG['AAPL Ret'] = AAPL_returns
AAPL_SMSG['SMSG Ret'] = SMSG_returns

AMZN_BABA['AMZN Ret'] = AMZN_returns
AMZN_BABA['BABA Ret'] = BABA_returns

AAPL_SMSG = AAPL_SMSG.iloc[T:]
AMZN_BABA = AMZN_BABA.iloc[T:]

# %%
AAPL_SMSG.head()
# Out:
#             AAPL Close  AAPL Volume  SMSG Close  SMSG Volume  AAPL Ret  \
# Date
# 2020-07-24   92.614998    185438800      41.734     10994535  2.599998
# 2020-07-27   94.809998    121214000      42.812     21054421  3.599998
# 2020-07-28   93.252502    103625600      45.122     48431566  4.845001
# 2020-07-29   95.040001     90329200      45.430     36476611  4.595001
# 2020-07-30   96.190002    158130000      45.430     19285354  4.990005
#
#             SMSG Ret
# Date
# 2020-07-24     1.001
# 2020-07-27     2.849
# 2020-07-28     4.081
# 2020-07-29     5.082
# 2020-07-30     4.774

# %%
AMZN_BABA.head()
# Out:
#             AMZN Close  AMZN Volume  BABA Close  BABA Volume   AMZN Ret  \
# Date
# 2020-07-24  150.445496    112648000  249.000000     17221500  13.725494
# 2020-07-27  152.760498     83410000  250.860001     18966900  15.031494
# 2020-07-28  150.016495     62534000  249.050003      9878700  15.373001
# 2020-07-29  151.676498     59482000  252.449997     11493600  17.657501
# 2020-07-30  152.593994    122566000  252.740005      7032900  14.653000
#
#              BABA Ret
# Date
# 2020-07-24  22.779999
# 2020-07-27  28.699997
# 2020-07-28  33.339996
# 2020-07-29  37.429993
# 2020-07-30  37.040009

# %%
import scipy.stats as stats

# Apply Pearson correlation
correlation, p_value = stats.pearsonr(AAPL_SMSG['AAPL Ret'].values, AAPL_SMSG['SMSG Ret'].values)

print("AAPL-SMSG Pearson correlation coefficient:", correlation)
print("\tp-value:", p_value)

correlation, p_value = stats.pearsonr(AMZN_BABA['AMZN Ret'].values, AMZN_BABA['BABA Ret'].values)

print("\nAMZN-BABA Pearson correlation coefficient:", correlation)
print("\tp-value:", p_value)
# Out:
# AAPL-SMSG Pearson correlation coefficient: 0.4131004285453169
# 	p-value: 5.5670413547235606e-30
#
# AMZN-BABA Pearson correlation coefficient: 0.25489106921438004
# 	p-value: 2.3839042329756787e-12

# %% [markdown]
# The null hypothesis used in the Pearson correlation test implemented by the `scipy.stats.pearsonr` function states that **there is no correlation between the two variables** in the population. In other words, the null hypothesis assumes that the true population correlation coefficient is zero.
#
# If the p-value is below a chosen significance level (e.g., 0.05), the null hypothesis can be rejected in favor of the alternative hypothesis, indicating that there is a statistically significant correlation between the variables.
#
# AAPL-SMSG:
# - A coefficient of `0.4131` indicates a moderate positive correlation between AAPL and SMSG stock returns. This means that, on average, when the stock returns of Apple increase, the stock returns of Samsung tend to increase as well, and vice versa.
# - In this case, the p-value is extremely small (`5.567e-30`), which is close to zero. This suggests that the observed correlation between AAPL and SMSG stock returns is highly unlikely to occur by chance.
#
# AMZN-BABA:
# - In this case, the coefficient indicates a weak positive correlation between AMZN and BABA stock returns. It suggests that there is a tendency for the stock returns of Amazon and Alibaba to move together, but the correlation is not as strong as in the AAPL-SMSG case.
# - The p-value for the AMZN-BABA correlation is also very small (`2.384e-12`), indicating that the observed correlation is statistically significant.

# %%
import seaborn as sn
corr_matrix = AAPL_SMSG.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %%
corr_matrix = AMZN_BABA.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ## **Creating train, validation and test dataset**

# %%
window_size = 7

AAPL_SMSG['AAPL Ret'] = AAPL_SMSG['AAPL Ret'].rolling(window=window_size).mean()
AAPL_SMSG['SMSG Ret'] = AAPL_SMSG['SMSG Ret'].rolling(window=window_size).mean()
AMZN_BABA['AMZN Ret'] = AMZN_BABA['AMZN Ret'].rolling(window=window_size).mean()
AMZN_BABA['BABA Ret'] = AMZN_BABA['BABA Ret'].rolling(window=window_size).mean()

AAPL_SMSG = AAPL_SMSG.dropna()
AMZN_BABA = AMZN_BABA.dropna()

AAPL_SMSG.head()
# Out:
#             AAPL Close  AAPL Volume  SMSG Close  SMSG Volume   AAPL Ret  \
# Date
# 2020-08-03  108.937500    308151200      43.736     21158940   7.681788
# 2020-08-04  109.665001    173071600      44.121     19419694   9.625002
# 2020-08-05  110.062500    121776800      43.813     17739706  11.523574
# 2020-08-06  113.902496    202428800      44.660     21625874  13.482859
# 2020-08-07  111.112503    198045600      44.275     18751717  15.020716
#
#             SMSG Ret
# Date
# 2020-08-03     3.553
# 2020-08-04     3.663
# 2020-08-05     3.641
# 2020-08-06     3.608
# 2020-08-07     3.399

# %%
from sklearn.preprocessing import MinMaxScaler

AAPL_SMSG_scaled = pd.DataFrame(index=AAPL_SMSG.index)
AMZN_BABA_scaled = pd.DataFrame(index=AMZN_BABA.index)

############################## Close Price ##############################
AAPL_Close_scaler = MinMaxScaler()
AMZN_Close_scaler = MinMaxScaler()

AAPL_close_prices = AAPL_SMSG['AAPL Close'].values.reshape(-1, 1)
AMZN_close_prices = AMZN_BABA['AMZN Close'].values.reshape(-1, 1)

AAPL_Close_scaler.fit(AAPL_close_prices)
AMZN_Close_scaler.fit(AMZN_close_prices)

AAPL_SMSG_scaled['AAPL Close'] = AAPL_Close_scaler.transform(AAPL_close_prices)
AMZN_BABA_scaled['AMZN Close'] = AMZN_Close_scaler.transform(AMZN_close_prices)
#########################################################################


##############################   Returns   ##############################
AAPL_Return_scaler = MinMaxScaler()
SMSG_Return_scaler = MinMaxScaler()
AMZN_Return_scaler = MinMaxScaler()
BABA_Return_scaler = MinMaxScaler()

AAPL_return = AAPL_SMSG['AAPL Ret'].values.reshape(-1, 1)
SMSG_return = AAPL_SMSG['SMSG Ret'].values.reshape(-1, 1)
AMZN_return = AMZN_BABA['AMZN Ret'].values.reshape(-1, 1)
BABA_return = AMZN_BABA['BABA Ret'].values.reshape(-1, 1)

AAPL_Return_scaler.fit(AAPL_return)
SMSG_Return_scaler.fit(SMSG_return)
AMZN_Return_scaler.fit(AMZN_return)
BABA_Return_scaler.fit(BABA_return)

AAPL_SMSG_scaled['AAPL Ret'] = AAPL_Return_scaler.transform(AAPL_return)
AAPL_SMSG_scaled['SMSG Ret'] = SMSG_Return_scaler.transform(SMSG_return)
AMZN_BABA_scaled['AMZN Ret'] = AMZN_Return_scaler.transform(AMZN_return)
AMZN_BABA_scaled['BABA Ret'] = BABA_Return_scaler.transform(BABA_return)
#########################################################################

# %%
# Get the column names except for the index column
columns = AAPL_SMSG_scaled.columns

# Set the number of rows and columns for subplots
num_rows = (len(columns) - 1) // 2 + 1
num_cols = 2

# Create subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 8))
fig.suptitle('Scaled Data: AAPL vs. SMSG')

# Flatten the axs array if there is only one row or one column
if num_rows == 1 or num_cols == 1:
    axs = [axs]

# Iterate over columns and plot each one
for i, column in enumerate(columns):
    row = i // num_cols
    col = i % num_cols
    if row < num_rows - 1:
        axs[row][col].set_xticklabels([])
    if col % 2 == 0:
      axs[row][col].plot(AAPL_SMSG_scaled.index, AAPL_SMSG_scaled[column], color='blue')
    else:
      axs[row][col].plot(AAPL_SMSG_scaled.index, AAPL_SMSG_scaled[column], color='red')
    axs[row][col].set_title(column)

# Remove any unused subplots
if len(columns) < num_rows * num_cols:
    for j in range(len(columns), num_rows * num_cols):
        row = j // num_cols
        col = j % num_cols
        fig.delaxes(axs[row][col])

fig.tight_layout()

# Rotate x-axis labels for better visibility
for ax_row in axs:
    for ax in ax_row:
        ax.tick_params(axis='x', rotation=45)

# Display the plot
plt.show()

# %%
def create_dataset(dataset, lookback, column):
    X_train = []
    Y_train = []

    for i in range(lookback, len(dataset)):
        X_train.append(dataset.iloc[i-lookback:i, dataset.columns != 'Data'].values)
        Y_train.append(dataset[column].iloc[i])

    return np.array(X_train), np.array(Y_train)

# %%
# Split the data into training, validation, and testing sets
AAPL_SMSG_train_size = int(len(AAPL_SMSG_scaled) * 0.7)
AAPL_SMSG_val_size   = int(len(AAPL_SMSG) * 0.2)
AAPL_SMSG_train_data = AAPL_SMSG_scaled[:AAPL_SMSG_train_size]
AAPL_SMSG_val_data   = AAPL_SMSG_scaled[AAPL_SMSG_train_size:AAPL_SMSG_train_size + AAPL_SMSG_val_size]
AAPL_SMSG_test_data  = AAPL_SMSG_scaled[AAPL_SMSG_train_size + AAPL_SMSG_val_size:]

AMZN_BABA_train_size = int(len(AMZN_BABA_scaled) * 0.7)
AMZN_BABA_val_size   = int(len(AMZN_BABA_scaled) * 0.2)
AMZN_BABA_train_data = AMZN_BABA_scaled[:AMZN_BABA_train_size]
AMZN_BABA_val_data   = AMZN_BABA_scaled[AMZN_BABA_train_size:AMZN_BABA_train_size + AMZN_BABA_val_size]
AMZN_BABA_test_data  = AMZN_BABA_scaled[AMZN_BABA_train_size + AMZN_BABA_val_size:]

# %%
AAPL_SMSG_X_train, AAPL_SMSG_Y_train = create_dataset(AAPL_SMSG_train_data, lookback=7, column='AAPL Ret')
AMZN_BABA_X_train, AMZN_BABA_Y_train = create_dataset(AMZN_BABA_train_data, lookback=7, column='AMZN Ret')

AAPL_SMSG_X_val, AAPL_SMSG_Y_val = create_dataset(AAPL_SMSG_val_data, lookback=7, column='AAPL Ret')
AMZN_BABA_X_val, AMZN_BABA_Y_val = create_dataset(AMZN_BABA_val_data, lookback=7, column='AMZN Ret')

AAPL_SMSG_X_test, AAPL_SMSG_Y_test = create_dataset(AAPL_SMSG_test_data, lookback=7, column='AAPL Ret')
AMZN_BABA_X_test, AMZN_BABA_Y_test = create_dataset(AMZN_BABA_test_data, lookback=7, column='AMZN Ret')

# %% [markdown]
# ## **Training and evaluating the model**

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import Dropout
from keras.utils import plot_model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

# %%
def smape(actual, predicted):
    numerator = tf.abs(actual - predicted)
    denominator = (tf.abs(actual) + tf.abs(predicted)) / 2.0

    smape_score = tf.reduce_mean(numerator / denominator) * 100.0

    return smape_score


def compile_and_fit(model,
                    X_train, Y_train,
                    X_val, Y_val,
                    file='LSTM_univariate_summary.png',
                    _patience=10, _min_delta=0.0001, _epochs=100, _batch_size=32, _early_stopping=False, _learning_rate=0.01, _verbose=1):

  if _early_stopping:
    early_stopping = EarlyStopping(monitor='val_smape',
                                   patience=_patience,
                                   min_delta=_min_delta,
                                   mode='min')

  _optimizer = Adam(learning_rate=_learning_rate)

  model.compile(loss=tf.keras.losses.MeanSquaredError(),
                optimizer=_optimizer,
                metrics=[smape])

  if _verbose != 0:
    model.summary()
    plot_model(model, to_file=file, show_shapes=True, show_layer_names=True)

  if _early_stopping:
    history = model.fit(X_train, Y_train,
                        batch_size=_batch_size,
                        epochs=_epochs,
                        validation_data=(X_val, Y_val),
                        callbacks=[early_stopping],
                        verbose=_verbose)
  else:
    history = model.fit(X_train, Y_train,
                        batch_size=_batch_size,
                        epochs=_epochs,
                        validation_data=(X_val, Y_val),
                        verbose=_verbose)
  return history

# %%
lookback = 7
features = 3

#################### AAPL ####################
AAPL_regressor = Sequential()

AAPL_regressor.add(LSTM(units=8,
                   input_shape=(lookback, features)))

AAPL_regressor.add(Dense(units=1))
##############################################

#################### AMZN ####################
AMZN_regressor = Sequential()

AMZN_regressor.add(LSTM(units=8,
                   input_shape=(lookback, features)))

AMZN_regressor.add(Dense(units=1))
##############################################

# %%
history = compile_and_fit(AAPL_regressor, X_train=AAPL_SMSG_X_train, Y_train=AAPL_SMSG_Y_train, X_val=AAPL_SMSG_X_val, Y_val=AAPL_SMSG_Y_val, _batch_size=32)

# Plot training loss and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 8)                 384
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 393
# Trainable params: 393
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 15/15 [==============================] - 10s 97ms/step - loss: 0.0920 - smape: 60.3109 - val_loss: 0.0282 - val_smape: 33.7765
# Epoch 2/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.0263 - smape: 31.5358 - val_loss: 0.0205 - val_smape: 30.0494
# Epoch 3/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0161 - smape: 25.3574 - val_loss: 0.0127 - val_smape: 23.9689
# Epoch 4/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0109 - smape: 22.0779 - val_loss: 0.0105 - val_smape: 24.4773
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0074 - smape: 18.5311 - val_loss: 0.0068 - val_smape: 18.6795
# Epoch 6/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0057 - smape: 16.7062 - val_loss: 0.0065 - val_smape: 17.2959
# Epoch 7/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0052 - smape: 16.2587 - val_loss: 0.0065 - val_smape: 17.1345
# Epoch 8/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0050 - smape: 15.8436 - val_loss: 0.0062 - val_smape: 16.4837
# Epoch 9/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0049 - smape: 15.9072 - val_loss: 0.0059 - val_smape: 16.6201
# Epoch 10/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0048 - smape: 15.6348 - val_loss: 0.0053 - val_smape: 15.5477
# Epoch 11/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0043 - smape: 14.7871 - val_loss: 0.0050 - val_smape: 14.6898
# Epoch 12/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0041 - smape: 14.7144 - val_loss: 0.0046 - val_smape: 14.0318
# Epoch 13/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0037 - smape: 14.1199 - val_loss: 0.0048 - val_smape: 15.3967
# Epoch 14/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0035 - smape: 13.6214 - val_loss: 0.0048 - val_smape: 15.4108
# Epoch 15/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0031 - smape: 13.1479 - val_loss: 0.0044 - val_smape: 14.8639
# Epoch 16/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0029 - smape: 12.5646 - val_loss: 0.0034 - val_smape: 12.6280
# Epoch 17/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0025 - smape: 12.0588 - val_loss: 0.0031 - val_smape: 12.1625
# Epoch 18/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0022 - smape: 11.4918 - val_loss: 0.0029 - val_smape: 12.2140
# Epoch 19/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0020 - smape: 10.8370 - val_loss: 0.0020 - val_smape: 9.2603
# Epoch 20/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0018 - smape: 10.5390 - val_loss: 0.0017 - val_smape: 8.9732
# Epoch 21/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0015 - smape: 9.5880 - val_loss: 0.0018 - val_smape: 10.0984
# Epoch 22/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0011 - smape: 8.7567 - val_loss: 0.0011 - val_smape: 6.8996
# Epoch 23/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0010 - smape: 8.2697 - val_loss: 0.0010 - val_smape: 6.9175
# Epoch 24/100
# 15/15 [==============================] - 0s 21ms/step - loss: 9.2087e-04 - smape: 7.8225 - val_loss: 8.7676e-04 - val_smape: 6.5082
# Epoch 25/100
# 15/15 [==============================] - 0s 18ms/step - loss: 8.6561e-04 - smape: 7.5886 - val_loss: 7.4333e-04 - val_smape: 5.7125
# Epoch 26/100
# 15/15 [==============================] - 0s 12ms/step - loss: 7.7216e-04 - smape: 7.4913 - val_loss: 6.4193e-04 - val_smape: 5.5886
# Epoch 27/100
# 15/15 [==============================] - 0s 16ms/step - loss: 8.1160e-04 - smape: 7.4764 - val_loss: 9.4108e-04 - val_smape: 6.8132
# Epoch 28/100
# 15/15 [==============================] - 0s 13ms/step - loss: 6.6475e-04 - smape: 6.9049 - val_loss: 6.4450e-04 - val_smape: 5.4927
# Epoch 29/100
# 15/15 [==============================] - 0s 19ms/step - loss: 6.2680e-04 - smape: 6.9090 - val_loss: 5.4840e-04 - val_smape: 4.8582
# Epoch 30/100
# 15/15 [==============================] - 0s 16ms/step - loss: 6.1692e-04 - smape: 6.8193 - val_loss: 5.7024e-04 - val_smape: 5.0761
# Epoch 31/100
# Epoch 94/100
# 15/15 [==============================] - 0s 10ms/step - loss: 2.8418e-04 - smape: 4.9824 - val_loss: 2.9017e-04 - val_smape: 3.7020
# Epoch 95/100
# 15/15 [==============================] - 0s 12ms/step - loss: 2.8497e-04 - smape: 5.0333 - val_loss: 3.3253e-04 - val_smape: 3.9255
# Epoch 96/100
# 15/15 [==============================] - 0s 10ms/step - loss: 2.7258e-04 - smape: 4.8656 - val_loss: 3.2037e-04 - val_smape: 3.8836
# Epoch 97/100
# 15/15 [==============================] - 0s 9ms/step - loss: 2.9055e-04 - smape: 5.3610 - val_loss: 2.7577e-04 - val_smape: 3.7273
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 2.6836e-04 - smape: 4.9339 - val_loss: 4.1355e-04 - val_smape: 5.0416
# Epoch 99/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.1728e-04 - smape: 5.4148 - val_loss: 2.7226e-04 - val_smape: 3.6521
# Epoch 100/100
# 15/15 [==============================] - 0s 7ms/step - loss: 3.1146e-04 - smape: 5.0475 - val_loss: 2.8059e-04 - val_smape: 3.7632

# %%
AAPL_predictions = AAPL_regressor.predict(AAPL_SMSG_X_test)

# Evaluate the model on the test dataset
loss = AAPL_regressor.evaluate(AAPL_SMSG_X_test, AAPL_SMSG_Y_test, batch_size=32)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4277e-04 - smape: 1.6387

# %%
# Plotting AAPL close price predictions
plt.figure(figsize=(12, 6))
plt.plot(AAPL_SMSG.index[-len(AAPL_SMSG_Y_test):].values, AAPL_Return_scaler.inverse_transform(AAPL_SMSG_Y_test.reshape(-1, 1)), label='Actual', color='magenta')
plt.plot(AAPL_SMSG.index[-len(AAPL_SMSG_Y_test):].values, AAPL_Return_scaler.inverse_transform(AAPL_predictions.reshape(-1, 1)), label='Predicted', color='blue')
plt.title('AAPL - Returns', fontweight='bold')
plt.xlabel('Time', fontweight='bold')
plt.ylabel('ROI [T = ' + str(T) + ' days]', fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %%
history = compile_and_fit(AMZN_regressor, X_train=AMZN_BABA_X_train, Y_train=AMZN_BABA_Y_train, X_val=AMZN_BABA_X_val, Y_val=AMZN_BABA_Y_val, _batch_size=32)

# Plot training loss and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 8)                 384
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 393
# Trainable params: 393
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 2s 35ms/step - loss: 0.0407 - smape: 32.3821 - val_loss: 0.0656 - val_smape: 51.1961
# Epoch 2/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0132 - smape: 19.7610 - val_loss: 0.0204 - val_smape: 24.5122
# Epoch 3/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0087 - smape: 17.0217 - val_loss: 0.0052 - val_smape: 12.2246
# Epoch 4/100
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0053 - smape: 14.0865 - val_loss: 0.0039 - val_smape: 8.5679
# Epoch 5/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0045 - smape: 12.6600 - val_loss: 0.0049 - val_smape: 10.6737
# Epoch 6/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0043 - smape: 12.2169 - val_loss: 0.0051 - val_smape: 11.1805
# Epoch 7/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0040 - smape: 12.1553 - val_loss: 0.0033 - val_smape: 8.0965
# Epoch 8/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0033 - smape: 11.1461 - val_loss: 0.0035 - val_smape: 8.7587
# Epoch 9/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0030 - smape: 10.4988 - val_loss: 0.0031 - val_smape: 7.8898
# Epoch 10/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0028 - smape: 10.1147 - val_loss: 0.0029 - val_smape: 7.9271
# Epoch 11/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0023 - smape: 9.5116 - val_loss: 0.0029 - val_smape: 8.1484
# Epoch 12/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0021 - smape: 8.9277 - val_loss: 0.0027 - val_smape: 8.0432
# Epoch 13/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0019 - smape: 8.8381 - val_loss: 0.0025 - val_smape: 7.6836
# Epoch 14/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0018 - smape: 8.4052 - val_loss: 0.0024 - val_smape: 7.7104
# Epoch 15/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0015 - smape: 8.0292 - val_loss: 0.0022 - val_smape: 7.4856
# Epoch 16/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0014 - smape: 7.5025 - val_loss: 0.0022 - val_smape: 7.7271
# Epoch 17/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0012 - smape: 7.3936 - val_loss: 0.0021 - val_smape: 7.7606
# Epoch 18/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0011 - smape: 7.0140 - val_loss: 0.0024 - val_smape: 8.1826
# Epoch 19/100
# 16/16 [==============================] - 0s 9ms/step - loss: 9.2208e-04 - smape: 6.3752 - val_loss: 0.0017 - val_smape: 6.9795
# Epoch 20/100
# 16/16 [==============================] - 0s 9ms/step - loss: 7.3891e-04 - smape: 6.1158 - val_loss: 0.0019 - val_smape: 7.4554
# Epoch 21/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.5490e-04 - smape: 5.5873 - val_loss: 0.0014 - val_smape: 6.5501
# Epoch 22/100
# 16/16 [==============================] - 0s 6ms/step - loss: 7.9049e-04 - smape: 6.0510 - val_loss: 0.0025 - val_smape: 8.8213
# Epoch 23/100
# 16/16 [==============================] - 0s 7ms/step - loss: 6.8642e-04 - smape: 5.8939 - val_loss: 0.0012 - val_smape: 6.2467
# Epoch 24/100
# 16/16 [==============================] - 0s 7ms/step - loss: 6.0154e-04 - smape: 5.9450 - val_loss: 0.0012 - val_smape: 6.0640
# Epoch 25/100
# 16/16 [==============================] - 0s 7ms/step - loss: 4.0031e-04 - smape: 4.6221 - val_loss: 0.0012 - val_smape: 6.2462
# Epoch 26/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.8389e-04 - smape: 4.8308 - val_loss: 0.0015 - val_smape: 6.9088
# Epoch 27/100
# 16/16 [==============================] - 0s 6ms/step - loss: 4.7675e-04 - smape: 5.1075 - val_loss: 0.0012 - val_smape: 6.0273
# Epoch 28/100
# 16/16 [==============================] - 0s 8ms/step - loss: 4.2096e-04 - smape: 4.8193 - val_loss: 9.1614e-04 - val_smape: 5.4178
# Epoch 29/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.8574e-04 - smape: 5.0055 - val_loss: 0.0011 - val_smape: 5.9866
# Epoch 30/100
# 16/16 [==============================] - 0s 6ms/step - loss: 3.1983e-04 - smape: 4.5705 - val_loss: 0.0011 - val_smape: 5.8695
# Epoch 31/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.3247e-04 - smape: 4.6073 - val_loss: 0.0014 - val_smape: 6.8301
# Epoch 32/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.9574e-04 - smape: 4.2191 - val_loss: 0.0010 - val_smape: 5.8401
# Epoch 33/100
# 16/16 [==============================] - 0s 6ms/step - loss: 3.2898e-04 - smape: 4.6090 - val_loss: 0.0015 - val_smape: 7.0819
# Epoch 34/100
# 16/16 [==============================] - 0s 8ms/step - loss: 4.2585e-04 - smape: 4.9682 - val_loss: 0.0014 - val_smape: 6.8778
# Epoch 35/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.9539e-04 - smape: 4.6193 - val_loss: 0.0010 - val_smape: 5.8471
# Epoch 36/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.1947e-04 - smape: 4.5814 - val_loss: 7.7168e-04 - val_smape: 5.0166
# Epoch 37/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.9879e-04 - smape: 5.0256 - val_loss: 9.8231e-04 - val_smape: 5.6735
# Epoch 38/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.3267e-04 - smape: 4.5039 - val_loss: 0.0011 - val_smape: 5.9525
# Epoch 39/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.2048e-04 - smape: 4.7180 - val_loss: 9.6448e-04 - val_smape: 5.6385
# Epoch 40/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.5491e-04 - smape: 4.0851 - val_loss: 8.6928e-04 - val_smape: 5.3675
# Epoch 41/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.0284e-04 - smape: 4.6931 - val_loss: 6.8137e-04 - val_smape: 4.6973
# Epoch 42/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.9661e-04 - smape: 4.5851 - val_loss: 0.0011 - val_smape: 5.9622
# Epoch 43/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.4587e-04 - smape: 4.2060 - val_loss: 0.0011 - val_smape: 5.9049
# Epoch 44/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.5112e-04 - smape: 4.1837 - val_loss: 8.8636e-04 - val_smape: 5.4121
# Epoch 45/100
# 16/16 [==============================] - 0s 8ms/step - loss: 3.0237e-04 - smape: 4.4143 - val_loss: 7.5546e-04 - val_smape: 5.0143
# Epoch 46/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.8321e-04 - smape: 4.4705 - val_loss: 8.3649e-04 - val_smape: 5.2544
# Epoch 47/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.4266e-04 - smape: 4.7093 - val_loss: 8.5497e-04 - val_smape: 5.3166
# Epoch 48/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.3690e-04 - smape: 4.3344 - val_loss: 9.5892e-04 - val_smape: 5.6322
# Epoch 49/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.2929e-04 - smape: 4.5935 - val_loss: 7.8529e-04 - val_smape: 5.0942
# Epoch 50/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.7847e-04 - smape: 4.0877 - val_loss: 8.6431e-04 - val_smape: 5.3503
# Epoch 51/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.2111e-04 - smape: 4.1492 - val_loss: 0.0010 - val_smape: 5.9183
# Epoch 52/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.6209e-04 - smape: 4.4653 - val_loss: 8.0901e-04 - val_smape: 5.1653
# Epoch 53/100
# 16/16 [==============================] - 0s 6ms/step - loss: 2.4905e-04 - smape: 4.3896 - val_loss: 0.0012 - val_smape: 6.3423
# Epoch 54/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.3595e-04 - smape: 4.0539 - val_loss: 0.0012 - val_smape: 6.4350
# Epoch 55/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.7090e-04 - smape: 4.8408 - val_loss: 0.0012 - val_smape: 6.2886
# Epoch 56/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.4741e-04 - smape: 4.7621 - val_loss: 7.6359e-04 - val_smape: 5.0054
# Epoch 57/100
# 16/16 [==============================] - 0s 7ms/step - loss: 3.5874e-04 - smape: 4.5799 - val_loss: 7.1919e-04 - val_smape: 4.8563
# Epoch 58/100
# 16/16 [==============================] - 0s 8ms/step - loss: 3.0959e-04 - smape: 4.2764 - val_loss: 5.2529e-04 - val_smape: 4.0264
# Epoch 59/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.8541e-04 - smape: 4.0912 - val_loss: 8.1010e-04 - val_smape: 5.1651
# Epoch 60/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.1532e-04 - smape: 4.0123 - val_loss: 7.0805e-04 - val_smape: 4.8019
# Epoch 61/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.3478e-04 - smape: 3.9533 - val_loss: 6.7541e-04 - val_smape: 4.6842
# Epoch 62/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.2461e-04 - smape: 4.2408 - val_loss: 8.0465e-04 - val_smape: 5.1455
# Epoch 63/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.0682e-04 - smape: 4.0336 - val_loss: 8.8061e-04 - val_smape: 5.4222
# Epoch 64/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.0963e-04 - smape: 4.1709 - val_loss: 6.1844e-04 - val_smape: 4.5067
# Epoch 65/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.6319e-04 - smape: 4.8087 - val_loss: 5.7849e-04 - val_smape: 4.3422
# Epoch 66/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.7086e-04 - smape: 4.6324 - val_loss: 5.5901e-04 - val_smape: 4.2106
# Epoch 67/100
# 16/16 [==============================] - 0s 8ms/step - loss: 2.1689e-04 - smape: 4.2070 - val_loss: 5.5556e-04 - val_smape: 4.2854
# Epoch 68/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2
100
# 16/16 [==============================] - 0s 8ms/step - loss: 2.6085e-04 - smape: 4.4795 - val_loss: 3.8548e-04 - val_smape: 3.4014
# Epoch 99/100
# 16/16 [==============================] - 0s 7ms/step - loss: 2.2337e-04 - smape: 4.0283 - val_loss: 4.6969e-04 - val_smape: 3.7930
# Epoch 100/100
# 16/16 [==============================] - 0s 7ms/step - loss: 1.8190e-04 - smape: 4.1090 - val_loss: 6.7892e-04 - val_smape: 4.7190

# %%
AMZN_predictions = AMZN_regressor.predict(AMZN_BABA_X_test)

# Evaluate the model on the test dataset
loss = AMZN_regressor.evaluate(AMZN_BABA_X_test, AMZN_BABA_Y_test, batch_size=32)
# Out:
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7029e-04 - smape: 1.5959

# %%
# Plotting AAPL close price predictions
plt.figure(figsize=(12, 6))
plt.plot(AMZN_BABA.index[-len(AMZN_BABA_Y_test):].values, AMZN_Return_scaler.inverse_transform(AMZN_BABA_Y_test.reshape(-1, 1)), label='Actual', color='magenta')
plt.plot(AMZN_BABA.index[-len(AMZN_BABA_Y_test):].values, AMZN_Return_scaler.inverse_transform(AMZN_predictions.reshape(-1, 1)), label='Predicted', color='blue')
plt.title('AMZN - Returns', fontweight='bold')
plt.xlabel('Time', fontweight='bold')
plt.ylabel('ROI [T = ' + str(T) + ' days]', fontweight='bold')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
from sklearn.metrics import mean_squared_error

def grid_search(ticker, X_train, Y_train, X_val, Y_val, _early_stopping=True, lookback=7, features=3):
  # Hyperparameter grid
  param_grid = {
      'units': [4, 8, 16, 32],
      'batch_size': [8, 16, 32],
      'epochs': [100, 250],
      'patience': [10, 25],
      'learning_rate': [0.01, 0.001]
  }

  # Initialize variables for best hyperparameters and best performance
  best_score = float('inf')
  best_params = {}

  # Iterate through the hyperparameter grid
  for _units in param_grid['units']:
      for _batch_size in param_grid['batch_size']:
          for _epochs in param_grid['epochs']:
              for _patience in param_grid['patience']:
                  for l_rate in param_grid['learning_rate']:

                      # For reproducibility
                      np.random.seed(24)
                      tf.random.set_seed(24)

                      # Build the RNN model
                      regressor = Sequential()
                      regressor.add(LSTM(units=_units,
                                              batch_input_shape=(_batch_size, lookback, features)))
                      regressor.add(Dense(units=1))

                      # Compile and fit the model
                      history = compile_and_fit(model=regressor,
                                                X_train = X_train,
                                                Y_train = Y_train,
                                                X_val   = X_val,
                                                Y_val   = Y_val,
                                                _early_stopping = _early_stopping,
                                                _patience       = _patience,
                                                _min_delta      = 1e-5,
                                                _epochs         = _epochs,
                                                _batch_size     = _batch_size,
                                                _learning_rate  = l_rate,
                                                _verbose        = 0)

                      # Get MSE of the validation set
                      mse = history.history['val_loss']

                      # Check if current model's performance is better than the best so far
                      if mse < best_score:
                          best_score = mse
                          best_params = {'units': _units, 'batch_size': _batch_size, 'epochs': _epochs, 'patience': _patience, 'learning_rate': l_rate}
                          print("NEW Best", best_params)
                          print('\t\tMSE: ', mse)

  # Print the best hyperparameters and best MSE score
  print(str(ticker) + " - Best Hyperparameters:", best_params)
  print(str(ticker) + " - Best MSE Score:", best_score)

# %%
grid_search(ticker='AAPL',
            X_train = AAPL_SMSG_X_train,
            Y_train = AAPL_SMSG_Y_train,
            X_val   = AAPL_SMSG_X_val,
            Y_val   = AAPL_SMSG_Y_val,
            _early_stopping=True)
# Out:
# 2/2 [==============================] - 0s 7ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 100, 'patience': 10, 'learning_rate': 0.01}
# 		MSE:  0.001127226897595704
# 2/2 [==============================] - 1s 11ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 100, 'patience': 10, 'learning_rate': 0.001}
# 		MSE:  0.00014134123989668464
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 250, 'patience': 10, 'learning_rate': 0.01}
# 		MSE:  0.0001136234001416129
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 250, 'patience': 25, 'learning_rate': 0.01}
# 		MSE:  0.00010595538433958262
# 2/2 [==============================] - 0s 6ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 250, 'patience': 25, 'learning_rate': 0.001}
# 		MSE:  9.695703551989921e-05
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 1s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# NEW Best {'units': 8, 'batch_size': 8, 'epochs': 250, 'patience': 25, 'learning_rate': 0.001}
# 		MSE:  8.797830998581046e-05
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# NEW Best {'units': 16, 'batch_size': 8, 'epochs': 250, 'patience': 25, 'learning_rate': 0.001}
# 		MSE:  8.760256806245646e-05
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 1s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 1s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 7ms/step
# AAPL - Best Hyperparameters: {'units': 16, 'batch_size': 8, 'epochs': 250, 'patience': 25, 'learning_rate': 0.001}
# AAPL - Best MSE Score: 8.760256806245646e-05

# %%
grid_search(ticker='AMZN',
            X_train = AMZN_BABA_X_train,
            Y_train = AMZN_BABA_Y_train,
            X_val   = AMZN_BABA_X_val,
            Y_val   = AMZN_BABA_Y_val,
            _early_stopping=True)
# Out:
# 3/3 [==============================] - 1s 5ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 100, 'patience': 10, 'learning_rate': 0.01}
# 		MSE:  0.0008658264711338457
# 3/3 [==============================] - 0s 5ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 100, 'patience': 10, 'learning_rate': 0.001}
# 		MSE:  0.00027671250828296945
# 3/3 [==============================] - 0s 5ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 100, 'patience': 25, 'learning_rate': 0.01}
# 		MSE:  9.925989341171778e-05
# 3/3 [==============================] - 1s 4ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b7f17e62a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 6ms/step
# NEW Best {'units': 4, 'batch_size': 8, 'epochs': 250, 'patience': 10, 'learning_rate': 0.01}
# 		MSE:  7.203463401030566e-05
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7b7f1d427c70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 8ms/step
# 3/3 [==============================] - 2s 7ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 1s 5ms/step
# NEW Best {'units': 4, 'batch_size': 32, 'epochs': 250, 'patience': 25, 'learning_rate': 0.01}
# 		MSE:  7.105322083230115e-05
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# AMZN - Best Hyperparameters: {'units': 4, 'batch_size': 32, 'epochs': 250, 'patience': 25, 'learning_rate': 0.01}
# AMZN - Best MSE Score: 7.105322083230115e-05
